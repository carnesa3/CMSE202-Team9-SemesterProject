# %%
#some imports 
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#importing our data
forest = pd.read_csv('wood_removal.csv')
sea = pd.read_csv('sealevelepa.csv')
forest.head()
# Out:
#        country        1990        1991        1992        1993        1994  \
# 0  Afghanistan   2160000.0   2210000.0   2290000.0   2400000.0   2510000.0
# 1      Albania   2080000.0   2560000.0   2560000.0    595000.0    409000.0
# 2      Algeria    124000.0    172000.0    139000.0    239000.0    166000.0
# 3       Angola   3190000.0   3280000.0   3380000.0   3670000.0   3750000.0
# 4    Argentina  10200000.0  10400000.0  11700000.0  10300000.0  10800000.0
#
#          1995        1996        1997        1998  ...        2002  \
# 0   2610000.0   2720000.0   2810000.0   2880000.0  ...   3110000.0
# 1    409000.0    409000.0    409000.0     27700.0  ...    305000.0
# 2    194000.0    190000.0    203000.0    222000.0  ...    121000.0
# 3   3780000.0   3840000.0   3930000.0   4050000.0  ...   4420000.0
# 4  11600000.0  11500000.0  11500000.0  12300000.0  ...  11500000.0
#
#          2003        2004        2005        2006        2007        2008  \
# 0   3150000.0   3190000.0   3230000.0   3260000.0   3290000.0   3320000.0
# 1    296000.0    296000.0    296000.0    296000.0    430000.0    430000.0
# 2    164000.0    184000.0    141000.0    141000.0    152000.0    121000.0
# 3   4500000.0   4580000.0   4670000.0   4750000.0   4840000.0   4920000.0
# 4  13000000.0  15000000.0  14300000.0  14000000.0  13700000.0  13100000.0
#
#          2009        2010        2011
# 0   3360000.0   3400000.0   3400000.0
# 1    430000.0    430000.0    430000.0
# 2    139000.0    135000.0    119000.0
# 3   5010000.0   5110000.0   5200000.0
# 4  14100000.0  15000000.0  15200000.0
#
# [5 rows x 23 columns]

# %%
len(forest)
# Out:
# 173

# %%
forest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 23 columns):
# country    173 non-null object
# 1990       146 non-null float64
# 1991       147 non-null float64
# 1992       153 non-null float64
# 1993       155 non-null float64
# 1994       155 non-null float64
# 1995       157 non-null float64
# 1996       158 non-null float64
# 1997       159 non-null float64
# 1998       163 non-null float64
# 1999       165 non-null float64
# 2000       167 non-null float64
# 2001       168 non-null float64
# 2002       169 non-null float64
# 2003       169 non-null float64
# 2004       171 non-null float64
# 2005       171 non-null float64
# 2006       171 non-null float64
# 2007       171 non-null float64
# 2008       171 non-null float64
# 2009       171 non-null float64
# 2010       171 non-null float64
# 2011       172 non-null float64
# dtypes: float64(22), object(1)
# memory usage: 31.2+ KB

# %%
forest_reduced = forest[['2004', '2005','2006','2007','2008','2009','2010']]

# %%
forest_reduced.head(3)
# Out:
#         2004       2005       2006       2007       2008       2009       2010
# 0  3190000.0  3230000.0  3260000.0  3290000.0  3320000.0  3360000.0  3400000.0
# 1   296000.0   296000.0   296000.0   430000.0   430000.0   430000.0   430000.0
# 2   184000.0   141000.0   141000.0   152000.0   121000.0   139000.0   135000.0

# %%
forest_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 7 columns):
# 2004    171 non-null float64
# 2005    171 non-null float64
# 2006    171 non-null float64
# 2007    171 non-null float64
# 2008    171 non-null float64
# 2009    171 non-null float64
# 2010    171 non-null float64
# dtypes: float64(7)
# memory usage: 9.6 KB

# %%
plt.plot(forest_reduced)
# Out:
# [<matplotlib.lines.Line2D at 0x1a24ba1210>,
#  <matplotlib.lines.Line2D at 0x1a24ba1490>,
#  <matplotlib.lines.Line2D at 0x1a24ba1650>,
#  <matplotlib.lines.Line2D at 0x1a24ba1810>,
#  <matplotlib.lines.Line2D at 0x1a24ba19d0>,
#  <matplotlib.lines.Line2D at 0x1a24ba1b90>,
#  <matplotlib.lines.Line2D at 0x1a24ba1dd0>]

# %%
#sea = pd.read_csv('sealevels.txt', header=None)
#sep=" "

# %%
sea.head(3)
# Out:
#          Year  CSIRO Adjusted Sea Level  Lower Error Bound  Upper Error Bound  \
# 0  1880-03-15                  0.000000          -0.952756           0.952756
# 1  1881-03-15                  0.220472          -0.732283           1.173228
# 2  1882-03-15                 -0.440945          -1.346457           0.464567
#
#    NOAA Adjusted Sea Level
# 0                      NaN
# 1                      NaN
# 2                      NaN

# %%
sea_reduced = sea[['Year', 'CSIRO Adjusted Sea Level']]
sea_reduced.head(3)
# Out:
#          Year  CSIRO Adjusted Sea Level
# 0  1880-03-15                  0.000000
# 1  1881-03-15                  0.220472
# 2  1882-03-15                 -0.440945

# %%
sea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 5 columns):
# Year                        135 non-null object
# CSIRO Adjusted Sea Level    134 non-null float64
# Lower Error Bound           134 non-null float64
# Upper Error Bound           134 non-null float64
# NOAA Adjusted Sea Level     22 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 5.4+ KB

# %%
land = pd.read_csv('GlobalTemperature.csv')
   #Parenthesis give group of string, inside bracket you define information
                                                    #A-Za-z anything can be concluded, + to extend to wahtever side you want
                                                    #\. means to stop at the period
# land['Year'] = land['dt'].str.extract('\-',expand=True)
# #land['Year'] = land['dt'].str.extract('(+)\-',expand=True)
# land['Year'][:5]
land.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3192 entries, 0 to 3191
# Data columns (total 9 columns):
# dt                                           3192 non-null object
# LandAverageTemperature                       3180 non-null float64
# LandAverageTemperatureUncertainty            3180 non-null float64
# LandMaxTemperature                           1992 non-null float64
# LandMaxTemperatureUncertainty                1992 non-null float64
# LandMinTemperature                           1992 non-null float64
# LandMinTemperatureUncertainty                1992 non-null float64
# LandAndOceanAverageTemperature               1992 non-null float64
# LandAndOceanAverageTemperatureUncertainty    1992 non-null float64
# dtypes: float64(8), object(1)
# memory usage: 224.6+ KB

# %%
land_reduced = land[['dt', 'LandAverageTemperature']]
#land_reduced.isnull.sum()
land_reduced.head()
# Out:
#            dt  LandAverageTemperature
# 0  1750-01-01                   3.034
# 1  1750-02-01                   3.083
# 2  1750-03-01                   5.626
# 3  1750-04-01                   8.490
# 4  1750-05-01                  11.573

# %%
land1=land_reduced['dt'].str[:4]
land1.head()
# Out:
# 0    1750
# 1    1750
# 2    1750
# 3    1750
# 4    1750
# Name: dt, dtype: object

# %%
land2 = land1.astype('float64', copy=False)
landata=[]
for i in land2:
    landata.append(land['LandAverageTemperature'])
#landata

# %%
plt.scatter(land1,land['LandAverageTemperature'])

# %%
co2 = pd.read_csv('yearly_co2_emissions_1000_tonnes.csv')
co2 = co2.dropna(axis = 1)

# %%
co2.head()
# Out:
#        country      2012      2013      2014
# 0  Afghanistan   10800.0   10000.0    9810.0
# 1      Albania    4910.0    5060.0    5720.0
# 2      Algeria  130000.0  134000.0  145000.0
# 3      Andorra     488.0     477.0     462.0
# 4       Angola   33400.0   32600.0   34800.0

# %%
co2_real = pd.read_csv('API_EN.ATM.CO2E.PC_DS2_en_csv_v2_511927.csv', header = [0,1])

# %%
co2_real = co2_real.dropna()

# %%
co2_real
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Country Name, Country Code, Indicator Name, Indicator Code, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0, 2007.0, 2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0), (Aruba, ABW, CO2 emissions (metric tons per capita), EN.ATM.CO2E.PC, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, 2.86831939212055, 7.235198033412581, 10.0261792105306, 10.6347325992922, 26.3745032100275, 26.0461298009966, 21.4425588041328, 22.000786163522, 21.036245110821397, 20.7719361585578, 20.318353365384603, 20.4268177083943, 20.587669145364803, 20.311566765912, 26.194875238021897, 25.9340244138733, 25.671161782044802, 26.420452085716896, 26.5172934158421, 27.200707780588, 26.9477259654482, 27.895022821125803, 26.229552674677898, 25.915322063969196, 24.670528873107802, 24.507516218176104, 13.157722308892401, 8.35356100776471, 8.41006417792511, nan, nan, nan), (Afghanistan, AFG, CO2 emissions (metric tons per capita), EN.ATM.CO2E.PC, 0.0460567126299034, 0.0535888350504558, 0.0737208308323819, 0.0741607248298659, 0.0861736143685528, 0.10128491249779, 0.107398880925452, 0.123409531952439, 0.11514249751082599, 0.0865098566374047, 0.149651474425259, 0.16520832089735998, 0.12999559417753, 0.13536658754345898, 0.15450324056731102, 0.167612355743012, 0.153557886047794, 0.18152216644271998, 0.161894231687439, 0.167066411474234, 0.13178291845827098, 0.150614656164027, 0.163103934258866, 0.20122430455911897, 0.2319613460576, 0.29395693222969504, 0.267771904296961, 0.269229595949307, 0.24682327129313503, 0.233882194583363, 0.21064341941885398, 0.18336355235879503, 0.0961965810608727, 0.0850871075160703, 0.0758064942125158, 0.0686398621540897, 0.0624346107290676, 0.0566423445298646, 0.0527632181252538, 0.0407225399194997, 0.0372347810411313, 0.0378461357038751, 0.0473773238699389, 0.0504813357583004, 0.0384100431744103, 0.0517439645638815, 0.0624275315344817, 0.0838928056625891, 0.151720912092499, 0.23839854131104898, 0.289987629819143, 0.406424217113203, 0.34514878290355294, 0.310341014879365, 0.293946407148718, nan, nan, nan), (Angola, AGO, CO2 emissions (metric tons per capita), EN.ATM.CO2E.PC, 0.10083533564940199, 0.0822037967470503, 0.210531477092341, 0.20273730345395602, 0.213560349319029, 0.20589092585307897, 0.268941436867758, 0.172101693676556, 0.28971809111152197, 0.48023402043060703, 0.608223599046918, 0.5645482360961179, 0.721245978268245, 0.7512398871965079, 0.7207763799697701, 0.6285689066059229, 0.451353518485931, 0.46922117648151895, 0.6947369474939821, 0.6830629479749921, 0.640966402195152, 0.611135119645444, 0.519354626128818, 0.5513485741039971, 0.520982856139637, 0.47190277210483, 0.451618882781396, 0.544085132259045, 0.46350829640270896, 0.43729546197189206, 0.431743614699926, 0.41553083007202, 0.41052293186433897, 0.44172109794770203, 0.288119067989055, 0.7870325472424, 0.726233460982052, 0.496361244979515, 0.475815159521396, 0.57708291408973, 0.581961496322796, 0.574316054293958, 0.722958874715979, 0.500225395509936, 1.0018781174790998, 0.985736354999963, 1.10501902714063, 1.20313399963445, 1.1850004936477099, 1.2344250744671799, 1.24409153765549, 1.25268084136928, 1.3302185671929698, 1.25377616969393, 1.29030677595566, nan, nan, nan), (Albania, ALB, CO2 emissions (metric tons per capita), EN.ATM.CO2E.PC, 1.25819492789657, 1.3741860465116298, 1.43995596379167, 1.1816811441597501, 1.11174195966673, 1.1660990427345501, 1.3330554645866202, 1.3637463001081598, 1.51955127697956, 1.5589675720986997, 1.75323990542637, 1.9894979233065502, 2.51591439803203, 2.30389741687392, 1.8490066907107903, 1.91063363704144,  ...
#
# [265 rows x 0 columns]
